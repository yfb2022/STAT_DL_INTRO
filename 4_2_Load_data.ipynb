# %% [markdown]
# <a href="https://colab.research.google.com/github/yfb2022/STAT_DL_INTRO/blob/main/4_2_Load_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# 데이터셋 함수 정의
class CustomDataset(Dataset):
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  def __len__(self):
    return len(self.x_data)

  def __getitem__(self, idx):
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1)

    def forward(self, x):
        return self.linear(x)

model = MultivariateLinearRegressionModel()
optimizer = optim.SGD(model.parameters(), lr=1e-5)
dataset = CustomDataset()

# 데이터 로더 설정
dataloader = DataLoader(
    dataset,
    batch_size = 2, # by 2^
    shuffle = True
)

nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    x_train, y_train = samples
    prediction = model(x_train)
    cost = F.mse_loss(prediction, y_train)
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx +1, len(dataloader), cost.item()
    ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 33824.730469
# Epoch    0/20 Batch 2/3 Cost: 24151.628906
# Epoch    0/20 Batch 3/3 Cost: 7013.383789
# Epoch    1/20 Batch 1/3 Cost: 1158.449463
# Epoch    1/20 Batch 2/3 Cost: 190.889374
# Epoch    1/20 Batch 3/3 Cost: 158.564499
# Epoch    2/20 Batch 1/3 Cost: 36.763203
# Epoch    2/20 Batch 2/3 Cost: 1.105779
# Epoch    2/20 Batch 3/3 Cost: 0.059040
# Epoch    3/20 Batch 1/3 Cost: 4.451718
# Epoch    3/20 Batch 2/3 Cost: 0.271491
# Epoch    3/20 Batch 3/3 Cost: 7.945730
# Epoch    4/20 Batch 1/3 Cost: 1.749892
# Epoch    4/20 Batch 2/3 Cost: 2.029772
# Epoch    4/20 Batch 3/3 Cost: 5.056047
# Epoch    5/20 Batch 1/3 Cost: 1.534420
# Epoch    5/20 Batch 2/3 Cost: 5.757420
# Epoch    5/20 Batch 3/3 Cost: 1.123530
# Epoch    6/20 Batch 1/3 Cost: 4.970718
# Epoch    6/20 Batch 2/3 Cost: 2.563492
# Epoch    6/20 Batch 3/3 Cost: 0.719504
# Epoch    7/20 Batch 1/3 Cost: 2.400882
# Epoch    7/20 Batch 2/3 Cost: 3.126683
# Epoch    7/20 Batch 3/3 Cost: 1.099688
# Epoch    8/20 Batch 1/3 Cost: 0.449413
# Epoch    8/20 Batch 2/3 Cost: 2.540607
# Epoch    8/20 Batch 3/3 Cost: 5.656219
# Epoch    9/20 Batch 1/3 Cost: 3.072281
# Epoch    9/20 Batch 2/3 Cost: 2.216878
# Epoch    9/20 Batch 3/3 Cost: 2.885478
# Epoch   10/20 Batch 1/3 Cost: 3.127073
# Epoch   10/20 Batch 2/3 Cost: 3.151471
# Epoch   10/20 Batch 3/3 Cost: 2.176588
# Epoch   11/20 Batch 1/3 Cost: 3.153854
# Epoch   11/20 Batch 2/3 Cost: 1.553788
# Epoch   11/20 Batch 3/3 Cost: 2.361533
# Epoch   12/20 Batch 1/3 Cost: 1.899917
# Epoch   12/20 Batch 2/3 Cost: 1.195618
# Epoch   12/20 Batch 3/3 Cost: 6.786321
# Epoch   13/20 Batch 1/3 Cost: 2.658508
# Epoch   13/20 Batch 2/3 Cost: 2.568966
# Epoch   13/20 Batch 3/3 Cost: 3.346338
# Epoch   14/20 Batch 1/3 Cost: 2.836667
# Epoch   14/20 Batch 2/3 Cost: 2.432452
# Epoch   14/20 Batch 3/3 Cost: 3.013458
# Epoch   15/20 Batch 1/3 Cost: 2.613579
# Epoch   15/20 Batch 2/3 Cost: 3.039372
# Epoch   15/20 Batch 3/3 Cost: 2.080952
# Epoch   16/20 Batch 1/3 Cost: 3.146221
# Epoch   16/20 Batch 2/3 Cost: 2.386483
# Epoch   16/20 Batch 3/3 Cost: 2.710609
# Epoch   17/20 Batch 1/3 Cost: 1.827062
# Epoch   17/20 Batch 2/3 Cost: 2.256158
# Epoch   17/20 Batch 3/3 Cost: 5.624184
# Epoch   18/20 Batch 1/3 Cost: 1.560442
# Epoch   18/20 Batch 2/3 Cost: 2.806214
# Epoch   18/20 Batch 3/3 Cost: 2.646430
# Epoch   19/20 Batch 1/3 Cost: 3.271081
# Epoch   19/20 Batch 2/3 Cost: 1.772170
# Epoch   19/20 Batch 3/3 Cost: 1.078636
# Epoch   20/20 Batch 1/3 Cost: 2.021096
# Epoch   20/20 Batch 2/3 Cost: 2.996839
# Epoch   20/20 Batch 3/3 Cost: 1.286481
